# %%
import xml.etree.ElementTree as ET
import os
from glob import glob

# %%
XML_PATH = '..\\dataset\\train_images'
CLASSES_PATH = '..\\dataset\\classes_7.txt'
TXT_PATH = '..\\dataset\\train_images\\annotation.txt'

# %%
'''loads the classes'''
def get_classes(classes_path):
    with open(classes_path) as f:
        class_names = f.readlines()
    class_names = [c.strip() for c in class_names]
    return class_names

# %%
classes = get_classes(CLASSES_PATH)
assert len(classes) > 0, 'no class names detected!'
print(f'num classes: {len(classes)}')
# Out:
# num classes: 7

# %%
# glob(XML_PATH+'\\**\\*.xml',recursive=True)

# %%
# for path in glob(XML_PATH+'/**/*.xml',recursive=True):
# #     print('\\'.join(path.split('\\')[0:-2]))
#     print(path.split('\\')[-3])

# %%
# output file
list_file = open(TXT_PATH, 'w')

for path in glob(XML_PATH+'/**/*.xml',recursive=True):
    in_file = open(path, encoding="utf-8")

    # Parse .xml file
    tree = ET.parse(in_file)
    root = tree.getroot()
    # Write object information to .txt file
    file_name = root.find('filename').text
    print(path.split('\\')[-3]+'\\images\\'+file_name)
    list_file.write(path.split('\\')[-3]+'\\images\\'+file_name)
    for obj in root.iter('object'):
        cls = obj.find('name').text 
        cls_id = classes.index(cls)
        xmlbox = obj.find('bndbox')
        b = (int(xmlbox.find('xmin').text), int(xmlbox.find('ymin').text), int(xmlbox.find('xmax').text), int(xmlbox.find('ymax').text))
        list_file.write(" " + ",".join([str(a) for a in b]) + ',' + str(cls_id))
    list_file.write('\n')
list_file.close()
# Out:
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_001.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_002.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_003.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_004.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_005.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_006.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_007.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_008.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_009.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_010.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_011.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_012.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_013.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_014.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_015.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_016.jpg
# 00_ChaetodonSpeculum\images\ChaetodonSpeculum_017.jpg
# ...
